# %% [markdown]
# # 1.6 awk
# This notebook will demonstrate the basics of using awk to extract specific fields from within data files.

# %% [markdown]
# #### manual inspection of `artists.txt`
#
# There are at least two options for loading `artists.txt` into your favorite spreadsheet program:
#
# * you already have the file on your computer somewhere on your file system, so you can load it from there (if you can figure it out)
# * you can download the text file from https://raw.githubusercontent.com/SuLab/Applied-Bioinformatics/master/Module-1_bash-jupyter-git/data/art/artists.txt
#
# Note that every row has four columns.

# %% [markdown]
# #### confirm using awk that each row has four columns
# Find and fix the error.
#
# ```
# %%bash
# awk '{print NF}' artists.txt
# ```

# %%
# %%bash
# awk 'BEGIN{FS="\t"}{print NF}' data/art/artists.txt
# Out:
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4

# %% [markdown]
# #### Print the third column
# Find and fix the error.
# ```
# %%bash
# awk '{print $3}' artists.txt
# ```

# %%
# %%bash
# awk 'BEGIN{FS="\t"}{print $3}' data/art/artists.txt
# Out:
# Baroque
# Romanticism
# Romanticism
# Romanticism
# Baroque
# Romanticism
# Baroque
# Realism
# Northern Renaissance
# Realism
# Romanticism
# Baroque
# Baroque
# Early Renaissance
# Medieval
# Early Renaissance
# Realism
# Medieval
# Medieval
# Early Renaissance
# High Renaissance
# Early Renaissance
# Baroque
# Baroque
# Baroque
# Rococo
# Neoclassicism
# Impressionism
# Baroque
# Baroque
# Mannerism
# Baroque
# Baroque
# Rococo
# Romanticism
# Baroque
# Baroque
# Rococo
# Baroque
# Baroque
# Mannerism
# Romanticism
# Rococo
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Neoclassicism
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Mannerism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Romanticism
# Romanticism
# Romanticism
# Rococo
# Baroque
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Rococo
# Rococo
# Rococo
# Neoclassicism
# Romanticism
# Northern Renaissance
# Romanticism
# Romanticism
# Baroque
# Baroque
# Romanticism
# Northern Renaissance
# Baroque
# Baroque
# Neoclassicism
# Rococo
# Mannerism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Northern Renaissance
# Romanticism
# Mannerism
# Realism
# Early Renaissance
# High Renaissance
# Mannerism
# Realism
# Baroque
# High Renaissance
# Baroque
# Romanticism
# Mannerism
# Baroque
# Realism
# Romanticism
# Baroque
# Baroque
# Baroque
# Realism
# Neoclassicism
# Neoclassicism
# Baroque
# Baroque
# Baroque
# Baroque
# Baroque
# Early Renaissance
# Baroque
# Baroque
# Northern Renaissance
# Northern Renaissance
# Neoclassicism
# Medieval
# Early Renaissance
# Medieval
# Early Renaissance
# Medieval
# High Renaissance
# High Renaissance
# Neoclassicism
# Realism
# Rococo
# Medieval
# Early Renaissance
# Baroque
# Medieval
# Early Renaissance
# Mannerism
# Mannerism
# Early Renaissance
# Early Renaissance

# %% [markdown]
# #### Use `uniq` (and another command) to find the most common art periods
# Find and fix the error(s).
# ```
# %%bash
# awk '{print $3}' artists.txt | uniq
# ```

# %%
# %%bash
# awk 'BEGIN{FS="\t"}{print $3}' data/art/artists.txt | sort | uniq
# Out:
# Baroque
# Early Renaissance
# High Renaissance
# Impressionism
# Mannerism
# Medieval
# Neoclassicism
# Northern Renaissance
# Realism
# Rococo
# Romanticism

# %% [markdown]
# ### HW1: Repeat the above command (finding the most common art periods) restricting to Dutch painters only.
# HINT: start by searching/filtering for Dutch painters...

# %%
# %%bash
# awk 'BEGIN{FS="\t"}{print $3}' data/art/artists.txt | sort | uniq -c | sort -rn
# Out:
#      61 Baroque
#      18 Romanticism
#      12 Early Renaissance
#      10 Rococo
#      10 Neoclassicism
#      10 Mannerism
#       9 Realism
#       8 Medieval
#       6 Northern Renaissance
#       5 High Renaissance
#       1 Impressionism

# %% [markdown]
# ### HW1: Repeat the above command (finding the most common art periods) restricting to Dutch painters only.
# HINT: start by searching/filtering for Dutch painters...

# %%
# %%bash
# grep painter data/art/artists.txt | grep "Dutch painter" | awk 'BEGIN{FS="\t"}{print $3}' | sort | uniq -c | sort -k1rn
# Out:
#      17 Baroque
#       4 Romanticism
#       2 Rococo
#       1 Neoclassicism
#       1 Realism

# %% [markdown]
# ### HW2: Find the most common last names among all artists in `artists.txt`.
# HINT: you will use `awk`, `sort`, and `uniq`, and you may use one or more of those commands multiple times

# %%
# %%bash
# awk 'BEGIN{FS="\t"}{print $1}' data/art/artists.txt | awk 'BEGIN{FS=","}{print $1}' | sort | uniq -c | sort -rn
# Out:
#       5 KOBELL
#       5 KNIP
#       4 KONINCK
#       4 ALBERTI
#       4 ADAM
#       3 TENIERS
#       3 TARAVAL
#       2 TESSIN
#       2 TEMPESTA
#       2 TEDESCO
#       2 TASSAERT
#       2 TALENTI
#       2 TACCA
#       2 KNYFF
#       2 KNIJFF
#       2 KLODT
#       2 KISS
#       1 TETRODE
#       1 TESTELIN
#       1 TESTA
#       1 TERZIO
#       1 TERRENI
#       1 TERILLI
#       1 TERBRUGGHEN
#       1 TERBORCH
#       1 TENGNAGEL
#       1 TENERANI
#       1 TEMPEL
#       1 TEMANZA
#       1 TELEPY
#       1 TEERLINC
#       1 TAUNAY
#       1 TASSI
#       1 TASSEL
#       1 TARUFFI
#       1 TARSIA
#       1 TARGONE
#       1 TARDIEU
#       1 TARCHIANI
#       1 TARBELL
#       1 TANZIO DA VARALLO
#       1 TAMM
#       1 TAMAGNINO
#       1 TAMAGNI
#       1 TALPA
#       1 TADOLINI
#       1 TADDEO DI FERRARA (see CRIVELLI
#       1 TADDEO DI BARTOLO
#       1 TACCONE
#       1 KŘBKE
#       1 KOPISCH
#       1 KONRAD von Soest
#       1 KÖNIG
#       1 KOMPE
#       1 KOLUNIĆ
#       1 KOLLONITSCH
#       1 KOLBE
#       1 KOKORINOV
#       1 KOETS
#       1 KOERBECKE
#       1 KOEKKOEK
#       1 KOEDIJCK
#       1 KOEBERGER
#       1 KOCH
#       1 KOBERGER
#       1 KNÜPFER
#       1 KNOLLER
#       1 KNOBELSDORFF
#       1 KNELLER
#       1 KNEBEL
#       1 KLOCKER
#       1 KLINGER
#       1 KLESECKER
#       1 KLENZE
#       1 KLEINER
#       1 KINSOEN
#       1 KILIAN
#       1 ALBERTINELLI
#       1 ALBEREGNO
#       1 ALBANI
#       1 ALBA
#       1 AKOTANTOS
#       1 AKEN
#       1 AIVAZOVSKY
#       1 AGUADO LÓPEZ
#       1 AGRATE
#       1 AGOSTINO VENEZIANO (see MUSI
#       1 AGOSTINO DI GIOVANNI
#       1 AGOSTINO DI DUCCIO
#       1 AGNOLO DI VENTURA
#       1 AGNOLO DI POLO
#       1 AGNOLO DA SIENA (see AGNOLO DI VENTURA)
#       1 AGASSE
#       1 AERT VAN ORT
#       1 AERTSEN
#       1 AENVANCK
#       1 AELST
#       1 ADRIANO FIORENTINO
#       1 ADRIAEN VAN UTRECHT (see UTRECHT
#       1 ADRIAENSSEN
#       1 ADOLPHI
#       1 ADOLFZOON
#       1 ADLER
#       1 ADEMOLLO
#       1 ADELCRANTZ
#       1 ADAM-SALOMON
#       1 ACHENBACH
#       1 ACERO Y AREBO
#       1 ABONDIO
#       1 ABILDGAARD
#       1 ABEELE
#       1 ABBONDI
#       1 ABBATINI
#       1 ABBATI
#       1 ABBATE
#       1 ABAQUESNE
#       1 ABADIA
#       1 AAGAARD
#       1 AACHEN
